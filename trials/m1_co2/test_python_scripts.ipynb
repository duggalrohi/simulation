# %%
import h5py
import os
import sys
import matplotlib.pyplot as plt
import numpy as np

out = h5py.File('m1.h5',"r+")

z = out['cell_fields']['cell_geometry_centroid'][:, 1]

xmin = min(z)-49.9
xmax = max(z)+49.9

ymin = min(z)-49.9
ymax = max(z)+49.9

T = out['cell_fields']['fluid_temperature'][:, 200]
H = out['source_fields']['source_enthalpy'][:, 1]
time = out['time'][:, 0]

plt.plot(time*3.168808781402895e-8, H*1e-3, '-')
plt.xlabel('Time, yrs')
plt.ylabel('Enthalpy, kJ')
#plt.ylim(0,2))
#plt.xlim(0,10)
plt.show()
